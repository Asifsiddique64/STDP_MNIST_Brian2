# %%
import numpy as np
import matplotlib.cm as cmap
import time
import os.path
import scipy
import pickle
from struct import unpack
from brian2 import *
import brian2 as b2
from brian2tools import *

# specify the location of the MNIST data
MNIST_data_path = '/home/asif/lava-dl/Tasks/Task_7/Unsupervised_STDP/data/'

# %%
def get_labeled_data(picklename, bTrain = True):
    """Read input-vector (image) and target class (label, 0-9) and return
       it as list of tuples.
    """
    if os.path.isfile('%s.pickle' % picklename):
            with open('%s.pickle' % picklename, 'rb') as f:
                data = pickle.load(f)
    else:
        # Open the images with gzip in read binary mode
        if bTrain:
            images = open(MNIST_data_path + 'train-images-idx3-ubyte','rb')
            labels = open(MNIST_data_path + 'train-labels-idx1-ubyte','rb')
        else:
            images = open(MNIST_data_path + 't10k-images-idx3-ubyte','rb')
            labels = open(MNIST_data_path + 't10k-labels-idx1-ubyte','rb')
        # Get metadata for images
        images.read(4)  # skip the magic_number
        number_of_images = unpack('>I', images.read(4))[0]
        rows = unpack('>I', images.read(4))[0]
        cols = unpack('>I', images.read(4))[0]
        # Get metadata for labels
        labels.read(4)  # skip the magic_number
        N = unpack('>I', labels.read(4))[0]

        if number_of_images != N:
            raise Exception('number of labels did not match the number of images')
        # Get the data
        x = np.zeros((N, rows, cols), dtype=np.uint8)  # Initialize numpy array
        y = np.zeros((N, 1), dtype=np.uint8)  # Initialize numpy array
        for i in range(N):
            if i % 1000 == 0:
                print("i: %i" % i)
            x[i] = [[unpack('>B', images.read(1))[0] for unused_col in range(cols)]  for unused_row in range(rows) ]
            y[i] = unpack('>B', labels.read(1))[0]

        data = {'x': x, 'y': y, 'rows': rows, 'cols': cols}
        pickle.dump(data, open("%s.pickle" % picklename, "wb"))
    return data

def get_matrix_from_file(fileName):
    offset = len(ending) + 4
    if fileName[-4-offset] == 'X':
        n_src = n_input
    else:
        if fileName[-3-offset]=='e':
            n_src = n_e
        else:
            n_src = n_i
    if fileName[-1-offset]=='e':
        n_tgt = n_e
    else:
        n_tgt = n_i
    readout = np.load(fileName)
    print (readout.shape, fileName)
    value_arr = np.zeros((n_src, n_tgt))
    if not readout.shape == (0,):
        value_arr[np.int32(readout[:,0]), np.int32(readout[:,1])] = readout[:,2]
    return value_arr


def save_connections(ending = ''):
    print ('save connections')
    for connName in save_conns:
        conn = connections[connName]
        connListSparse = zip(conn.i, conn.j, conn.w)
        np.save('/home/asif/lava-dl/Tasks/Task_8/Brian2STDPMNIST/weights/' + connName + ending, connListSparse)

def save_theta(ending = ''):
    print ('save theta')
    for pop_name in population_names:
        np.save('/home/asif/lava-dl/Tasks/Task_8/Brian2STDPMNIST/weights/theta_' + pop_name + ending, neuron_groups[pop_name + 'e'].theta)

def normalize_weights():
    for connName in connections:
        if connName[1] == 'e' and connName[3] == 'e':
            len_source = len(connections[connName].source)
            len_target = len(connections[connName].target)
            connection = np.zeros((len_source, len_target))
            connection[connections[connName].i, connections[connName].j] = connections[connName].w
            temp_conn = np.copy(connection)
            colSums = np.sum(temp_conn, axis = 0)
            colFactors = weight['ee_input']/colSums
            for j in range(n_e):#
                temp_conn[:,j] *= colFactors[j]
            connections[connName].w = temp_conn[connections[connName].i, connections[connName].j]

def get_2d_input_weights():
    name = 'XeAe'
    weight_matrix = np.zeros((n_input, n_e))
    n_e_sqrt = int(np.sqrt(n_e))
    n_in_sqrt = int(np.sqrt(n_input))
    num_values_col = n_e_sqrt*n_in_sqrt
    num_values_row = num_values_col
    rearranged_weights = np.zeros((num_values_col, num_values_row))
    connMatrix = np.zeros((n_input, n_e))
    connMatrix[connections[name].i, connections[name].j] = connections[name].w
    weight_matrix = np.copy(connMatrix)

    for i in range(n_e_sqrt):
        for j in range(n_e_sqrt):
                rearranged_weights[i*n_in_sqrt : (i+1)*n_in_sqrt, j*n_in_sqrt : (j+1)*n_in_sqrt] = \
                    weight_matrix[:, i + j*n_e_sqrt].reshape((n_in_sqrt, n_in_sqrt))
    return rearranged_weights


def plot_2d_input_weights():
    name = 'XeAe'
    weights = get_2d_input_weights()
    fig = b2.figure(fig_num, figsize = (18, 18))
    im2 = b2.imshow(weights, interpolation = "nearest", vmin = 0, vmax = wmax_ee, cmap = cmap.get_cmap('hot_r'))
    b2.colorbar(im2)
    b2.title('weights of connection' + name)
    fig.canvas.draw()
    return im2, fig

def update_2d_input_weights(im, fig):
    weights = get_2d_input_weights()
    im.set_array(weights)
    fig.canvas.draw()
    return im

def get_current_performance(performance, current_example_num):
    current_evaluation = int(current_example_num/update_interval)
    start_num = current_example_num - update_interval
    end_num = current_example_num
    difference = outputNumbers[start_num:end_num, 0] - input_numbers[start_num:end_num]
    correct = len(np.where(difference == 0)[0])
    performance[current_evaluation] = correct / float(update_interval) * 100
    return performance

def plot_performance(fig_num):
    num_evaluations = int(num_examples/update_interval)
    time_steps = range(0, num_evaluations)
    performance = np.zeros(num_evaluations)
    fig = b2.figure(fig_num, figsize = (5, 5))
    fig_num += 1
    ax = fig.add_subplot(111)
    im2, = ax.plot(time_steps, performance) #my_cmap
    b2.ylim(ymax = 100)
    b2.title('Classification performance')
    fig.canvas.draw()
    return im2, performance, fig_num, fig

def update_performance_plot(im, performance, current_example_num, fig):
    performance = get_current_performance(performance, current_example_num)
    im.set_ydata(performance)
    fig.canvas.draw()
    return im, performance

def get_recognized_number_ranking(assignments, spike_rates):
    summed_rates = [0] * 10
    num_assignments = [0] * 10
    for i in range(10):
        num_assignments[i] = len(np.where(assignments == i)[0])
        if num_assignments[i] > 0:
            summed_rates[i] = np.sum(spike_rates[assignments == i]) / num_assignments[i]
    return np.argsort(summed_rates)[::-1]

def get_new_assignments(result_monitor, input_numbers):
    assignments = np.zeros(n_e)
    input_nums = np.asarray(input_numbers)
    maximum_rate = [0] * n_e
    for j in range(10):
        num_assignments = len(np.where(input_nums == j)[0])
        if num_assignments > 0:
            rate = np.sum(result_monitor[input_nums == j], axis = 0) / num_assignments
            for i in range(n_e):
                if rate[i] > maximum_rate[i]:
                    maximum_rate[i] = rate[i]
                    assignments[i] = j
    return assignments

# %%
start = time.time()
training = get_labeled_data(MNIST_data_path + 'training')
end = time.time()
print ('time needed to load training set:', end - start)

start = time.time()
testing = get_labeled_data(MNIST_data_path + 'testing', bTrain = False)
end = time.time()
print ('time needed to load test set:', end - start)
# Out:
# time needed to load training set: 0.02130413055419922
# time needed to load test set: 0.0031118392944335938

# %%
test_mode = True

np.random.seed(0)
data_path = '/home/asif/lava-dl/Tasks/Task_8/Brian2STDPMNIST/'
if test_mode:
    weight_path = '/home/asif/lava-dl/Tasks/Task_8/Brian2STDPMNIST/weights/'
    num_examples = 10000 * 1
    use_testing_set = True
    do_plot_performance = False
    record_spikes = True
    ee_STDP_on = False
    update_interval = num_examples
else:
    weight_path = '/home/asif/lava-dl/Tasks/Task_8/Brian2STDPMNIST/random/'
    num_examples = 60000 * 3
    use_testing_set = False
    do_plot_performance = True
    if num_examples <= 60000:
        record_spikes = True
    else:
        record_spikes = True
    ee_STDP_on = True


ending = ''
n_input = 784
n_e = 400
n_i = n_e
single_example_time =   0.35 * b2.second #
resting_time = 0.15 * b2.second
runtime = num_examples * (single_example_time + resting_time)
if num_examples <= 10000:
    update_interval = num_examples
    weight_update_interval = 20
else:
    update_interval = 10000
    weight_update_interval = 100
if num_examples <= 60000:
    save_connections_interval = 10000
else:
    save_connections_interval = 10000
    update_interval = 10000

v_rest_e = -65. * b2.mV
v_rest_i = -60. * b2.mV
v_reset_e = -65. * b2.mV
v_reset_i = -45. * b2.mV
v_thresh_e = -52. * b2.mV
v_thresh_i = -40. * b2.mV
refrac_e = 5. * b2.ms
refrac_i = 2. * b2.ms

weight = {}
delay = {}
input_population_names = ['X']
population_names = ['A']
input_connection_names = ['XA']
save_conns = ['XeAe']
input_conn_names = ['ee_input']
recurrent_conn_names = ['ei', 'ie']
weight['ee_input'] = 78.
delay['ee_input'] = (0*b2.ms,10*b2.ms)
delay['ei_input'] = (0*b2.ms,5*b2.ms)
input_intensity = 2.
start_input_intensity = input_intensity

tc_pre_ee = 20*b2.ms
tc_post_1_ee = 20*b2.ms
tc_post_2_ee = 40*b2.ms
nu_ee_pre =  0.0001      # learning rate
nu_ee_post = 0.01       # learning rate
wmax_ee = 1.0
exp_ee_pre = 0.2
exp_ee_post = exp_ee_pre
STDP_offset = 0.4

if test_mode:
    scr_e = 'v = v_reset_e; timer = 0*ms'
else:
    tc_theta = 1e7 * b2.ms
    theta_plus_e = 0.05 * b2.mV
    scr_e = 'v = v_reset_e; theta += theta_plus_e; timer = 0*ms'
offset = 20.0*b2.mV
v_thresh_e_str = '(v>(theta - offset + v_thresh_e)) and (timer>refrac_e)'
v_thresh_i_str = 'v>v_thresh_i'
v_reset_i_str = 'v=v_reset_i'


neuron_eqs_e = '''
        dv/dt = ((v_rest_e - v) + (I_synE+I_synI) / nS) / (100*ms)  : volt (unless refractory)
        I_synE = ge * nS *         -v                           : amp
        I_synI = gi * nS * (-100.*mV-v)                          : amp
        dge/dt = -ge/(1.0*ms)                                   : 1
        dgi/dt = -gi/(2.0*ms)                                  : 1
        '''
if test_mode:
    neuron_eqs_e += '\n  theta      :volt'
else:
    neuron_eqs_e += '\n  dtheta/dt = -theta / (tc_theta)  : volt'
neuron_eqs_e += '\n  dtimer/dt = 0.1  : second'

neuron_eqs_i = '''
        dv/dt = ((v_rest_i - v) + (I_synE+I_synI) / nS) / (10*ms)  : volt (unless refractory)
        I_synE = ge * nS *         -v                           : amp
        I_synI = gi * nS * (-85.*mV-v)                          : amp
        dge/dt = -ge/(1.0*ms)                                   : 1
        dgi/dt = -gi/(2.0*ms)                                  : 1
        '''
eqs_stdp_ee = '''
                post2before                            : 1
                dpre/dt   =   -pre/(tc_pre_ee)         : 1 (event-driven)
                dpost1/dt  = -post1/(tc_post_1_ee)     : 1 (event-driven)
                dpost2/dt  = -post2/(tc_post_2_ee)     : 1 (event-driven)
            '''
eqs_stdp_pre_ee = 'pre = 1.; w = clip(w + nu_ee_pre * post1, 0, wmax_ee)'
eqs_stdp_post_ee = 'post2before = post2; w = clip(w + nu_ee_post * pre * post2before, 0, wmax_ee); post1 = 1.; post2 = 1.'

b2.ion()
fig_num = 1
neuron_groups = {}
input_groups = {}
connections = {}
rate_monitors = {}
spike_monitors = {}
spike_counters = {}
result_monitor = np.zeros((update_interval,n_e))

neuron_groups['e'] = b2.NeuronGroup(n_e*len(population_names), neuron_eqs_e, threshold= v_thresh_e_str, refractory= refrac_e, reset= scr_e, method='euler')
neuron_groups['i'] = b2.NeuronGroup(n_i*len(population_names), neuron_eqs_i, threshold= v_thresh_i_str, refractory= refrac_i, reset= v_reset_i_str, method='euler')


#------------------------------------------------------------------------------
# create network population and recurrent connections
#------------------------------------------------------------------------------
for subgroup_n, name in enumerate(population_names):
    print( 'create neuron group', name)

    neuron_groups[name+'e'] = neuron_groups['e'][subgroup_n*n_e:(subgroup_n+1)*n_e]
    neuron_groups[name+'i'] = neuron_groups['i'][subgroup_n*n_i:(subgroup_n+1)*n_e]

    neuron_groups[name+'e'].v = v_rest_e - 40. * b2.mV
    neuron_groups[name+'i'].v = v_rest_i - 40. * b2.mV
    if test_mode or weight_path[-8:] == 'weights/':
        neuron_groups['e'].theta = np.load(weight_path + 'theta_' + name + ending + '.npy') * b2.volt
    else:
        neuron_groups['e'].theta = np.ones((n_e)) * 20.0*b2.mV

    print ('create recurrent connections')
    for conn_type in recurrent_conn_names:
        connName = name+conn_type[0]+name+conn_type[1]
        weightMatrix = get_matrix_from_file(weight_path + '../random/' + connName + ending + '.npy')
        model = 'w : 1'
        pre = 'g%s_post += w' % conn_type[0]
        post = ''
        if ee_STDP_on:
            if 'ee' in recurrent_conn_names:
                model += eqs_stdp_ee
                pre += '; ' + eqs_stdp_pre_ee
                post = eqs_stdp_post_ee
        connections[connName] = b2.Synapses(neuron_groups[connName[0:2]], neuron_groups[connName[2:4]],
                                                    model=model, on_pre=pre, on_post=post)
        connections[connName].connect(True) # all-to-all connection
        connections[connName].w = weightMatrix[connections[connName].i, connections[connName].j]

    print( 'create monitors for', name)
    rate_monitors[name+'e'] = b2.PopulationRateMonitor(neuron_groups[name+'e'])
    rate_monitors[name+'i'] = b2.PopulationRateMonitor(neuron_groups[name+'i'])
    spike_counters[name+'e'] = b2.SpikeMonitor(neuron_groups[name+'e'])

    if record_spikes:
        spike_monitors[name+'e'] = b2.SpikeMonitor(neuron_groups[name+'e'])
        spike_monitors[name+'i'] = b2.SpikeMonitor(neuron_groups[name+'i'])


#------------------------------------------------------------------------------
# create input population and connections from input populations
#------------------------------------------------------------------------------
pop_values = [0,0,0]
for i,name in enumerate(input_population_names):
    input_groups[name+'e'] = b2.PoissonGroup(n_input, 0*Hz)
    rate_monitors[name+'e'] = b2.PopulationRateMonitor(input_groups[name+'e'])

for name in input_connection_names:
    print ('create connections between', name[0], 'and', name[1])
    for connType in input_conn_names:
        connName = name[0] + connType[0] + name[1] + connType[1]
        weightMatrix = get_matrix_from_file(weight_path + connName + ending + '.npy')
        model = 'w : 1'
        pre = 'g%s_post += w' % connType[0]
        post = ''
        if ee_STDP_on:
            print('create STDP for connection', name[0]+'e'+name[1]+'e')
            model += eqs_stdp_ee
            pre += '; ' + eqs_stdp_pre_ee
            post = eqs_stdp_post_ee

        connections[connName] = b2.Synapses(input_groups[connName[0:2]], neuron_groups[connName[2:4]],
                                                    model=model, on_pre=pre, on_post=post)
        minDelay = delay[connType][0]
        maxDelay = delay[connType][1]
        deltaDelay = maxDelay - minDelay
        # TODO: test this
        connections[connName].connect(True) # all-to-all connection
        connections[connName].delay = 'minDelay + rand() * deltaDelay'
        connections[connName].w = weightMatrix[connections[connName].i, connections[connName].j]
# Out:
# create neuron group A
# create recurrent connections
# (400, 3) /home/asif/lava-dl/Tasks/Task_8/Brian2STDPMNIST/weights/../random/AeAi.npy
# (160000, 3) /home/asif/lava-dl/Tasks/Task_8/Brian2STDPMNIST/weights/../random/AiAe.npy
# create monitors for A
# create connections between X and A
# (313600, 3) /home/asif/lava-dl/Tasks/Task_8/Brian2STDPMNIST/weights/XeAe.npy

# %%
#------------------------------------------------------------------------------
# run the simulation and set inputs
#------------------------------------------------------------------------------

net = Network()
for obj_list in [neuron_groups, input_groups, connections, rate_monitors,
        spike_monitors, spike_counters]:
    for key in obj_list:
        net.add(obj_list[key])

previous_spike_count = np.zeros(n_e)
assignments = np.zeros(n_e)
input_numbers = [0] * num_examples
outputNumbers = np.zeros((num_examples, 10))
if not test_mode:
    input_weight_monitor, fig_weights = plot_2d_input_weights()
    fig_num += 1
if do_plot_performance:
    performance_monitor, performance, fig_num, fig_performance = plot_performance(fig_num)
for i,name in enumerate(input_population_names):
    input_groups[name+'e'].rates = 0 * Hz
net.run(0*second)
j = 0
while j < (int(num_examples)):
    if test_mode:
        if use_testing_set:
            spike_rates = testing['x'][j%10000,:,:].reshape((n_input)) / 8. *  input_intensity
        else:
            spike_rates = training['x'][j%60000,:,:].reshape((n_input)) / 8. *  input_intensity
    else:
        normalize_weights()
        spike_rates = training['x'][j%60000,:,:].reshape((n_input)) / 8. *  input_intensity
    input_groups['Xe'].rates = spike_rates * Hz
#     print 'run number:', j+1, 'of', int(num_examples)
    net.run(single_example_time, report='text')

    if j % update_interval == 0 and j > 0:
        assignments = get_new_assignments(result_monitor[:], input_numbers[j-update_interval : j])
    if j % weight_update_interval == 0 and not test_mode:
        update_2d_input_weights(input_weight_monitor, fig_weights)
    if j % save_connections_interval == 0 and j > 0 and not test_mode:
        save_connections(str(j))
        save_theta(str(j))

    current_spike_count = np.asarray(spike_counters['Ae'].count[:]) - previous_spike_count
    previous_spike_count = np.copy(spike_counters['Ae'].count[:])
    if np.sum(current_spike_count) < 5:
        input_intensity += 1
        for i,name in enumerate(input_population_names):
            input_groups[name+'e'].rates = 0 * Hz
        net.run(resting_time)
    else:
        result_monitor[j%update_interval,:] = current_spike_count
        if test_mode and use_testing_set:
            input_numbers[j] = testing['y'][j%10000][0]
        else:
            input_numbers[j] = training['y'][j%60000][0]
        outputNumbers[j,:] = get_recognized_number_ranking(assignments, result_monitor[j%update_interval,:])
        if j % 100 == 0 and j > 0:
            print ('runs done:', j, 'of', int(num_examples))
        if j % update_interval == 0 and j > 0:
            if do_plot_performance:
                unused, performance = update_performance_plot(performance_monitor, performance, j, fig_performance)
                print ('Classification performance', performance[:(j/float(update_interval))+1])
        for i,name in enumerate(input_population_names):
            input_groups[name+'e'].rates = 0 * Hz
        net.run(resting_time)
        input_intensity = start_input_intensity
        j += 1
# Out:
# INFO:root:building '_cython_magic_6702536c063b6ab6a43e497b3fb1b6b2' extension
# INFO:root:x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -I/home/asif/lava-dl/.venv/include -I/home/asif/lava-dl/.venv/lib/python3.10/site-packages/numpy/core/include -I/home/asif/lava-dl/.venv/lib/python3.10/site-packages/brian2/synapses -I/home/asif/lava-dl/.venv/include -I/usr/include/python3.10 -c /home/asif/.cython/brian_extensions/_cython_magic_6702536c063b6ab6a43e497b3fb1b6b2.cpp -o /home/asif/.cython/brian_extensions/home/asif/.cython/brian_extensions/_cython_magic_6702536c063b6ab6a43e497b3fb1b6b2.o -w -O3 -ffast-math -fno-finite-math-only -march=native -std=c++11
# INFO:root:x86_64-linux-gnu-g++ -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -g -fwrapv -O2 /home/asif/.cython/brian_extensions/home/asif/.cython/brian_extensions/_cython_magic_6702536c063b6ab6a43e497b3fb1b6b2.o -L/home/asif/lava-dl/.venv/lib -L/usr/lib/x86_64-linux-gnu -Wl,--enable-new-dtags,-R/home/asif/lava-dl/.venv/lib -o /home/asif/.cython/brian_extensions/_cython_magic_6702536c063b6ab6a43e497b3fb1b6b2.cpython-310-x86_64-linux-gnu.so
# INFO:root:building '_cython_magic_9cdab8fd33c5763d3e58cc4d5dfc57db' extension
# INFO:root:x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -I/home/asif/lava-dl/.venv/include -I/home/asif/lava-dl/.venv/lib/python3.10/site-packages/numpy/core/include -I/home/asif/lava-dl/.venv/lib/python3.10/site-packages/brian2/synapses -I/home/asif/lava-dl/.venv/include -I/usr/include/python3.10 -c /home/asif/.cython/brian_extensions/_cython_magic_9cdab8fd33c5763d3e58cc4d5dfc57db.cpp -o /home/asif/.cython/brian_extensions/home/asif/.cython/brian_extensions/_cython_magic_9cdab8fd33c5763d3e58cc4d5dfc57db.o -w -O3 -ffast-math -fno-finite-math-only -march=native -std=c++11
# INFO:root:x86_64-linux-gnu-g++ -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -g -fwrapv -O2 /home/asif/.cython/brian_extensions/home/asif/.cython/brian_extensions/_cython_magic_9cdab8fd33c5763d3e58cc4d5dfc57db.o -L/home/asif/lava-dl/.venv/lib -L/usr/lib/x86_64-linux-gnu -Wl,--enable-new-dtags,-R/home/asif/lava-dl/.venv/lib -o /home/asif/.cython/brian_extensions/_cython_magic_9cdab8fd33c5763d3e58cc4d5dfc57db.cpython-310-x86_64-linux-gnu.so
# INFO:root:building '_cython_magic_5ff52ed30d5a3c54427879733098d908' extension
# INFO:root:x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -I/home/asif/lava-dl/.venv/include -I/home/asif/lava-dl/.venv/lib/python3.10/site-packages/numpy/core/include -I/home/asif/lava-dl/.venv/lib/python3.10/site-packages/brian2/synapses -I/home/asif/lava-dl/.venv/include -I/usr/include/python3.10 -c /home/asif/.cython/brian_extensions/_cython_magic_5ff52ed30d5a3c54427879733098d908.cpp -o /home/asif/.cython/brian_extensions/home/asif/.cython/brian_extensions/_cython_magic_5ff52ed30d5a3c54427879733098d908.o -w -O3 -ffast-math -fno-finite-math-only -march=native -std=c++11
# INFO:root:x86_64-linux-gnu-g++ -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -g -fwrapv -O2 /home/asif/.cython/brian_extensions/home/asif/.cython/brian_extensions/_cython_magic_5ff52ed30d5a3c54427879733098d908.o -L/home/asif/lava-dl/.venv/lib -L/usr/lib/x86_64-linux-gnu -Wl,--enable-new-dtags,-R/home/asif/lava-dl/.venv/lib -o /home/asif/.cython/brian_extensions/_cython_magic_5ff52ed30d5a3c54427879733098d908.cpython-310-x86_64-linux-gnu.so
# INFO:root:building '_cython_magic_c5ca99eb5da3ac4dd84d3368a7272b2c' extension
# INFO:root:x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -I/home/asif/lava-dl/.venv/include -I/home/asif/lava-dl/.venv/lib/python3.10/site-packages/numpy/core/include -I/home/asif/lava-dl/.venv/lib/python3.10/site-packages/brian2/synapses -I/home/asif/lava-dl/.venv/lib/python3.10/site-packages/numpy/core/include -I/home/asif/lava-dl/.venv/lib/python3.10/site-packages/brian2/synapses -I/home/asif/lava-dl/.venv/include -I/usr/include/python3.10 -c /home/asif/.cython/brian_extensions/_cython_magic_c5ca99eb5da3ac4dd84d3368a7272b2c.cpp -o /home/asif/.cython/brian_extensions/home/asif/.cython/brian_extensions/_cython_magic_c5ca99eb5da3ac4dd84d3368a7272b2c.o -w -O3 -ffast-math -fno-finite-math-only -march=native -std=c++11
# INFO:root:x86_64-linux-gnu-g++ -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -g -fwrapv -O2 /home/asif/.cython/brian_extensions/home/asif/.cython/brian_extensions/_cython_magic_c5ca99eb5da3ac4dd84d3368a7272b2c.o -L/home/asif/lava-dl/.venv/lib -L/usr/lib/x86_64-linux-gnu -Wl,--enable-new-dtags,-R/home/asif/lava-dl/.venv/lib -o /home/asif/.cython/brian_extensions/_cython_magic_c5ca99eb5da3ac4dd84d3368a7272b2c.cpython-310-x86_64-linux-gnu.so
# INFO:root:building '_cython_magic_9d23c902fb25196dee5bddaf2e39e61f' extension
# INFO:root:x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -I/home/asif/lava-dl/.venv/include -I/home/asif/lava-dl/.venv/lib/python3.10/site-packages/numpy/core/include -I/home/asif/lava-dl/.venv/lib/python3.10/site-packages/brian2/synapses -I/home/asif/lava-dl/.venv/include -I/usr/include/python3.10 -c /home/asif/.cython/brian_extensions/_cython_magic_9d23c902fb25196dee5bddaf2e39e61f.cpp -o /home/asif/.cython/brian_extensions/home/asif/.cython/brian_extensions/_cython_magic_9d23c902fb25196dee5bddaf2e39e61f.o -w -O3 -ffast-math -fno-finite-math-only -march=native -std=c++11
# INFO:root:x86_64-linux-gnu-g++ -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -g -fwrapv -O2 /home/asif/.cython/brian_extensions/home/asif/.cython/brian_extensions/_cython_magic_9d23c902fb25196dee5bddaf2e39e61f.o -L/home/asif/lava-dl/.venv/lib -L/usr/lib/x86_64-linux-gnu -Wl,--enable-new-dtags,-R/home/asif/lava-dl/.venv/lib -o /home/asif/.cython/brian_extensions/_cython_magic_9d23c902fb25196dee5bddaf2e39e61f.cpython-310-x86_64-linux-gnu.so
# INFO:root:building '_cython_magic_0f6eb0dedc9d85d5aad7bd17ad80b249' extension
# INFO:root:x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -I/home/asif/lava-dl/.venv/include -I/home/asif/lava-dl/.venv/lib/python3.10/site-packages/numpy/core/include -I/home/asif/lava-dl/.venv/lib/python3.10/site-packages/brian2/synapses -I/home/asif/lava-dl/.venv/lib/python3.10/site-packages/numpy/core/include -I/home/asif/lava-dl/.venv/lib/python3.10/site-packages/brian2/synapses -I/home/asif/lava-dl/.venv/include -I/usr/include/python3.10 -c /home/asif/.cython/brian_extensions/_cython_magic_0f6eb0dedc9d85d5aad7bd17ad80b249.cpp -o /home/asif/.cython/brian_extensions/home/asif/.cython/brian_extensions/_cython_magic_0f6eb0dedc9d85d5aad7bd17ad80b249.o -w -O3 -ffast-math -fno-finite-math-only -march=native -std=c++11
# INFO:root:x86_64-linux-gnu-g++ -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -g -fwrapv -O2 /home/asif/.cython/brian_extensions/home/asif/.cython/brian_extensions/_cython_magic_0f6eb0dedc9d85d5aad7bd17ad80b249.o -L/home/asif/lava-dl/.venv/lib -L/usr/lib/x86_64-linux-gnu -Wl,--enable-new-dtags,-R/home/asif/lava-dl/.venv/lib -o /home/asif/.cython/brian_extensions/_cython_magic_0f6eb0dedc9d85d5aad7bd17ad80b249.cpython-310-x86_64-linux-gnu.so
# INFO:root:building '_cython_magic_0028a8ab430e061b53a30e15aded9310' extension
# INFO:root:x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -I/home/asif/lava-dl/.venv/include -I/home/asif/lava-dl/.venv/lib/python3.10/site-packages/numpy/core/include -I/home/asif/lava-dl/.venv/lib/python3.10/site-packages/brian2/synapses -I/home/asif/lava-dl/.venv/include -I/usr/include/python3.10 -c /home/asif/.cython/brian_extensions/_cython_magic_0028a8ab430e061b53a30e15aded9310.cpp -o /home/asif/.cython/brian_extensions/home/asif/.cython/brian_extensions/_cython_magic_0028a8ab430e061b53a30e15aded9310.o -w -O3 -ffast-math -fno-finite-math-only -march=native -std=c++11
# INFO:root:x86_64-linux-gnu-g++ -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -g -fwrapv -O2 /home/asif/.cython/brian_extensions/home/asif/.cython/brian_extensions/_cython_magic_0028a8ab430e061b53a30e15aded9310.o -L/home/asif/lava-dl/.venv/lib -L/usr/lib/x86_64-linux-gnu -Wl,--enable-new-dtags,-R/home/asif/lava-dl/.venv/lib -o /home/asif/.cython/brian_extensions/_cython_magic_0028a8ab430e061b53a30e15aded9310.cpython-310-x86_64-linux-gnu.so
# INFO:root:building '_cython_magic_d6f53de9e21b864b87ec914388fb7307' extension
# INFO:root:x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -I/home/asif/lava-dl/.venv/include -I/home/asif/lava-dl/.venv/lib/python3.10/site-packages/numpy/core/include -I/home/asif/lava-dl/.venv/lib/python3.10/site-packages/brian2/synapses -I/home/asif/lava-dl/.venv/lib/python3.10/site-packages/numpy/core/include -I/home/asif/lava-dl/.venv/lib/python3.10/site-packages/brian2/synapses -I/home/asif/lava-dl/.venv/include -I/usr/include/python3.10 -c /home/asif/.cython/brian_extensions/_cython_magic_d6f53de9e21b864b87ec914388fb7307.cpp -o /home/asif/.cython/brian_extensions/home/asif/.cython/brian_extensions/_cython_magic_d6f53de9e21b864b87ec914388fb7307.o -w -O3 -ffast-math -fno-finite-math-only -march=native -std=c++11
# INFO:root:x86_64-linux-gnu-g++ -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -g -fwrapv -O2 /home/asif/.cython/brian_extensions/home/asif/.cython/brian_extensions/_cython_magic_d6f53de9e21b864b87ec914388fb7307.o -L/home/asif/lava-dl/.venv/lib -L/usr/lib/x86_64-linux-gnu -Wl,--enable-new-dtags,-R/home/asif/lava-dl/.venv/lib -o /home/asif/.cython/brian_extensions/_cython_magic_d6f53de9e21b864b87ec914388fb7307.cpython-310-x86_64-linux-gnu.so
# INFO:root:building '_cython_magic_0e900637e3994f9f4fd2d4426b2937c8' extension
# INFO:root:x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -I/home/asif/lava-dl/.venv/include -I/home/asif/lava-dl/.venv/lib/python3.10/site-packages/numpy/core/include -I/home/asif/lava-dl/.venv/lib/python3.10/site-packages/brian2/synapses -I/home/asif/lava-dl/.venv/include -I/usr/include/python3.10 -c /home/asif/.cython/brian_extensions/_cython_magic_0e900637e3994f9f4fd2d4426b2937c8.cpp -o /home/asif/.cython/brian_extensions/home/asif/.cython/brian_extensions/_cython_magic_0e900637e3994f9f4fd2d4426b2937c8.o -w -O3 -ffast-math -fno-finite-math-only -march=native -std=c++11
# INFO:root:x86_64-linux-gnu-g++ -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -g -fwrapv -O2 /home/asif/.cython/brian_extensions/home/asif/.cython/brian_extensions/_cython_magic_0e900637e3994f9f4fd2d4426b2937c8.o -L/home/asif/lava-dl/.venv/lib -L/usr/lib/x86_64-linux-gnu -Wl,--enable-new-dtags,-R/home/asif/lava-dl/.venv/lib -o /home/asif/.cython/brian_extensions/_cython_magic_0e900637e3994f9f4fd2d4426b2937c8.cpython-310-x86_64-linux-gnu.so
# INFO:root:building '_cython_magic_06d591aac768d7350950d0a6d33fd605' extension
# INFO:root:x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -I/home/asif/lava-dl/.venv/include -I/home/asif/lava-dl/.venv/lib/python3.10/site-packages/numpy/core/include -I/home/asif/lava-dl/.venv/lib/python3.10/site-packages/brian2/synapses -I/home/asif/lava-dl/.venv/include -I/usr/include/python3.10 -c /home/asif/.cython/brian_extensions/_cython_magic_06d591aac768d7350950d0a6d33fd605.cpp -o /home/asif/.cython/brian_extensions/home/asif/.cython/brian_extensions/_cython_magic_06d591aac768d7350950d0a6d33fd605.o -w -O3 -ffast-math -fno-finite-math-only -march=native -std=c++11
# INFO:root:x86_64-linux-gnu-g++ -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -g -fwrapv -O2 /home/asif/.cython/brian_extensions/home/asif/.cython/brian_extensions/_cython_magic_06d591aac768d7350950d0a6d33fd605.o -L/home/asif/lava-dl/.venv/lib -L/usr/lib/x86_64-linux-gnu -Wl,--enable-new-dtags,-R/home/asif/lava-dl/.venv/lib -o /home/asif/.cython/brian_extensions/_cython_magic_06d591aac768d7350950d0a6d33fd605.cpython-310-x86_64-linux-gnu.so
# INFO:root:building '_cython_magic_332bd9e6ae28ce3e4203c27e01ce4281' extension
# INFO:root:x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -I/home/asif/lava-dl/.venv/include -I/home/asif/lava-dl/.venv/lib/python3.10/site-packages/numpy/core/include -I/home/asif/lava-dl/.venv/lib/python3.10/site-packages/brian2/synapses -I/home/asif/lava-dl/.venv/include -I/usr/include/python3.10 -c /home/asif/.cython/brian_extensions/_cython_magic_332bd9e6ae28ce3e4203c27e01ce4281.cpp -o /home/asif/.cython/brian_extensions/home/asif/.cython/brian_extensions/_cython_magic_332bd9e6ae28ce3e4203c27e01ce4281.o -w -O3 -ffast-math -fno-finite-math-only -march=native -std=c++11
# INFO:root:x86_64-linux-gnu-g++ -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -g -fwrapv -O2 /home/asif/.cython/brian_extensions/home/asif/.cython/brian_extensions/_cython_magic_332bd9e6ae28ce3e4203c27e01ce4281.o -L/home/asif/lava-dl/.venv/lib -L/usr/lib/x86_64-linux-gnu -Wl,--enable-new-dtags,-R/home/asif/lava-dl/.venv/lib -o /home/asif/.cython/brian_extensions/_cython_magic_332bd9e6ae28ce3e4203c27e01ce4281.cpython-310-x86_64-linux-gnu.so
# INFO:root:building '_cython_magic_a3da6d13eda4bfeb81c7e6bd914c0fe1' extension
# INFO:root:x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -I/home/asif/lava-dl/.venv/include -I/home/asif/lava-dl/.venv/lib/python3.10/site-packages/numpy/core/include -I/home/asif/lava-dl/.venv/lib/python3.10/site-packages/brian2/synapses -I/home/asif/lava-dl/.venv/include -I/usr/include/python3.10 -c /home/asif/.cython/brian_extensions/_cython_magic_a3da6d13eda4bfeb81c7e6bd914c0fe1.cpp -o /home/asif/.cython/brian_extensions/home/asif/.cython/brian_extensions/_cython_magic_a3da6d13eda4bfeb81c7e6bd914c0fe1.o -w -O3 -ffast-math -fno-finite-math-only -march=native -std=c++11
# INFO:root:x86_64-linux-gnu-g++ -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -g -fwrapv -O2 /home/asif/.cython/brian_extensions/home/asif/.cython/brian_extensions/_cython_magic_a3da6d13eda4bfeb81c7e6bd914c0fe1.o -L/home/asif/lava-dl/.venv/lib -L/usr/lib/x86_64-linux-gnu -Wl,--enable-new-dtags,-R/home/asif/lava-dl/.venv/lib -o /home/asif/.cython/brian_extensions/_cython_magic_a3da6d13eda4bfeb81c7e6bd914c0fe1.cpython-310-x86_64-linux-gnu.so
# INFO:root:building '_cython_magic_36fa8e6eae18449ceebf8c12c890a1b2' extension
# INFO:root:x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -I/home/asif/lava-dl/.venv/include -I/home/asif/lava-dl/.venv/lib/python3.10/site-packages/numpy/core/include -I/home/asif/lava-dl/.venv/lib/python3.10/site-packages/brian2/synapses -I/home/asif/lava-dl/.venv/lib/python3.10/site-packages/numpy/core/include -I/home/asif/lava-dl/.venv/lib/python3.10/site-packages/brian2/synapses -I/home/asif/lava-dl/.venv/include -I/usr/include/python3.10 -c /home/asif/.cython/brian_extensions/_cython_magic_36fa8e6eae18449ceebf8c12c890a1b2.cpp -o /home/asif/.cython/brian_extensions/home/asif/.cython/brian_extensions/_cython_magic_36fa8e6eae18449ceebf8c12c890a1b2.o -w -O3 -ffast-math -fno-finite-math-only -march=native -std=c++11
# INFO:root:x86_64-linux-gnu-g++ -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -g -fwrapv -O2 /home/asif/.cython/brian_extensions/home/asif/.cython/brian_extensions/_cython_magic_36fa8e6eae18449ceebf8c12c890a1b2.o -L/home/asif/lava-dl/.venv/lib -L/usr/lib/x86_64-linux-gnu -Wl,--enable-new-dtags,-R/home/asif/lava-dl/.venv/lib -o /home/asif/.cython/brian_extensions/_cython_magic_36fa8e6eae18449ceebf8c12c890a1b2.cpython-310-x86_64-linux-gnu.so
# INFO:root:building '_cython_magic_b462e2775bce2343e283c957b3904d1c' extension
# INFO:root:x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -I/home/asif/lava-dl/.venv/include -I/home/asif/lava-dl/.venv/lib/python3.10/site-packages/numpy/core/include -I/home/asif/lava-dl/.venv/lib/python3.10/site-packages/brian2/synapses -I/home/asif/lava-dl/.venv/include -I/usr/include/python3.10 -c /home/asif/.cython/brian_extensions/_cython_magic_b462e2775bce2343e283c957b3904d1c.cpp -o /home/asif/.cython/brian_extensions/home/asif/.cython/brian_extensions/_cython_magic_b462e2775bce2343e283c957b3904d1c.o -w -O3 -ffast-math -fno-finite-math-only -march=native -std=c++11
# INFO:root:x86_64-linux-gnu-g++ -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -g -fwrapv -O2 /home/asif/.cython/brian_extensions/home/asif/.cython/brian_extensions/_cython_magic_b462e2775bce2343e283c957b3904d1c.o -L/home/asif/lava-dl/.venv/lib -L/usr/lib/x86_64-linux-gnu -Wl,--enable-new-dtags,-R/home/asif/lava-dl/.venv/lib -o /home/asif/.cython/brian_extensions/_cython_magic_b462e2775bce2343e283c957b3904d1c.cpython-310-x86_64-linux-gnu.so
# INFO:root:building '_cython_magic_e737e4606374a07450b31f7b46ab71e0' extension
# INFO:root:x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -I/home/asif/lava-dl/.venv/include -I/home/asif/lava-dl/.venv/lib/python3.10/site-packages/numpy/core/include -I/home/asif/lava-dl/.venv/lib/python3.10/site-packages/brian2/synapses -I/home/asif/lava-dl/.venv/include -I/usr/include/python3.10 -c /home/asif/.cython/brian_extensions/_cython_magic_e737e4606374a07450b31f7b46ab71e0.cpp -o /home/asif/.cython/brian_extensions/home/asif/.cython/brian_extensions/_cython_magic_e737e4606374a07450b31f7b46ab71e0.o -w -O3 -ffast-math -fno-finite-math-only -march=native -std=c++11
# INFO:root:x86_64-linux-gnu-g++ -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -g -fwrapv -O2 /home/asif/.cython/brian_extensions/home/asif/.cython/brian_extensions/_cython_magic_e737e4606374a07450b31f7b46ab71e0.o -L/home/asif/lava-dl/.venv/lib -L/usr/lib/x86_64-linux-gnu -Wl,--enable-new-dtags,-R/home/asif/lava-dl/.venv/lib -o /home/asif/.cython/brian_extensions/_cython_magic_e737e4606374a07450b31f7b46ab71e0.cpython-310-x86_64-linux-gnu.so
# INFO:root:building '_cython_magic_304e3b03788d710c5b461e6d6afbf92f' extension
# INFO:root:x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -I/home/asif/lava-dl/.venv/include -I/home/asif/lava-dl/.venv/lib/python3.10/site-packages/numpy/core/include -I/home/asif/lava-dl/.venv/lib/python3.10/site-packages/brian2/synapses -I/home/asif/lava-dl/.venv/lib/python3.10/site-packages/numpy/core/include -I/home/asif/lava-dl/.venv/lib/python3.10/site-packages/brian2/synapses -I/home/asif/lava-dl/.venv/include -I/usr/include/python3.10 -c /home/asif/.cython/brian_extensions/_cython_magic_304e3b03788d710c5b461e6d6afbf92f.cpp -o /home/asif/.cython/brian_extensions/home/asif/.cython/brian_extensions/_cython_magic_304e3b03788d710c5b461e6d6afbf92f.o -w -O3 -ffast-math -fno-finite-math-only -march=native -std=c++11
# INFO:root:x86_64-linux-gnu-g++ -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -g -fwrapv -O2 /home/asif/.cython/brian_extensions/home/asif/.cython/brian_extensions/_cython_magic_304e3b03788d710c5b461e6d6afbf92f.o -L/home/asif/lava-dl/.venv/lib -L/usr/lib/x86_64-linux-gnu -Wl,--enable-new-dtags,-R/home/asif/lava-dl/.venv/lib -o /home/asif/.cython/brian_extensions/_cython_magic_304e3b03788d710c5b461e6d6afbf92f.cpython-310-x86_64-linux-gnu.so
# INFO:root:building '_cython_magic_eb6c763597466b31ecba67326e0f37bb' extension
# INFO:root:x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -I/home/asif/lava-dl/.venv/include -I/home/asif/lava-dl/.venv/lib/python3.10/site-packages/numpy/core/include -I/home/asif/lava-dl/.venv/lib/python3.10/site-packages/brian2/synapses -I/home/asif/lava-dl/.venv/include -I/usr/include/python3.10 -c /home/asif/.cython/brian_extensions/_cython_magic_eb6c763597466b31ecba67326e0f37bb.cpp -o /home/asif/.cython/brian_extensions/home/asif/.cython/brian_extensions/_cython_magic_eb6c763597466b31ecba67326e0f37bb.o -w -O3 -ffast-math -fno-finite-math-only -march=native -std=c++11
# INFO:root:x86_64-linux-gnu-g++ -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -g -fwrapv -O2 /home/asif/.cython/brian_extensions/home/asif/.cython/brian_extensions/_cython_magic_eb6c763597466b31ecba67326e0f37bb.o -L/home/asif/lava-dl/.venv/lib -L/usr/lib/x86_64-linux-gnu -Wl,--enable-new-dtags,-R/home/asif/lava-dl/.venv/lib -o /home/asif/.cython/brian_extensions/_cython_magic_eb6c763597466b31ecba67326e0f37bb.cpython-310-x86_64-linux-gnu.so
# INFO:root:building '_cython_magic_60f81df04d57c5920e4f2dd6c87ff3a6' extension
# INFO:root:x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -I/home/asif/lava-dl/.venv/include -I/home/asif/lava-dl/.venv/lib/python3.10/site-packages/numpy/core/include -I/home/asif/lava-dl/.venv/lib/python3.10/site-packages/brian2/synapses -I/home/asif/lava-dl/.venv/include -I/usr/include/python3.10 -c /home/asif/.cython/brian_extensions/_cython_magic_60f81df04d57c5920e4f2dd6c87ff3a6.cpp -o /home/asif/.cython/brian_extensions/home/asif/.cython/brian_extensions/_cython_magic_60f81df04d57c5920e4f2dd6c87ff3a6.o -w -O3 -ffast-math -fno-finite-math-only -march=native -std=c++11
# INFO:root:x86_64-linux-gnu-g++ -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -g -fwrapv -O2 /home/asif/.cython/brian_extensions/home/asif/.cython/brian_extensions/_cython_magic_60f81df04d57c5920e4f2dd6c87ff3a6.o -L/home/asif/lava-dl/.venv/lib -L/usr/lib/x86_64-linux-gnu -Wl,--enable-new-dtags,-R/home/asif/lava-dl/.venv/lib -o /home/asif/.cython/brian_extensions/_cython_magic_60f81df04d57c5920e4f2dd6c87ff3a6.cpython-310-x86_64-linux-gnu.so
# INFO:root:building '_cython_magic_6e9cd61a71a6e01472e4b801d6b9c67c' extension
# INFO:root:x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -I/home/asif/lava-dl/.venv/include -I/home/asif/lava-dl/.venv/lib/python3.10/site-packages/numpy/core/include -I/home/asif/lava-dl/.venv/lib/python3.10/site-packages/brian2/synapses -I/home/asif/lava-dl/.venv/lib/python3.10/site-packages/numpy/core/include -I/home/asif/lava-dl/.venv/lib/python3.10/site-packages/brian2/synapses -I/home/asif/lava-dl/.venv/include -I/usr/include/python3.10 -c /home/asif/.cython/brian_extensions/_cython_magic_6e9cd61a71a6e01472e4b801d6b9c67c.cpp -o /home/asif/.cython/brian_extensions/home/asif/.cython/brian_extensions/_cython_magic_6e9cd61a71a6e01472e4b801d6b9c67c.o -w -O3 -ffast-math -fno-finite-math-only -march=native -std=c++11
# INFO:root:x86_64-linux-gnu-g++ -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -g -fwrapv -O2 /home/asif/.cython/brian_extensions/home/asif/.cython/brian_extensions/_cython_magic_6e9cd61a71a6e01472e4b801d6b9c67c.o -L/home/asif/lava-dl/.venv/lib -L/usr/lib/x86_64-linux-gnu -Wl,--enable-new-dtags,-R/home/asif/lava-dl/.venv/lib -o /home/asif/.cython/brian_extensions/_cython_magic_6e9cd61a71a6e01472e4b801d6b9c67c.cpython-310-x86_64-linux-gnu.so
# INFO:root:building '_cython_magic_90417133dbca0c2bc9fd1c6311cfcedc' extension
# INFO:root:x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -I/home/asif/lava-dl/.venv/include -I/home/asif/lava-dl/.venv/lib/python3.10/site-packages/numpy/core/include -I/home/asif/lava-dl/.venv/lib/python3.10/site-packages/brian2/synapses -I/home/asif/lava-dl/.venv/include -I/usr/include/python3.10 -c /home/asif/.cython/brian_extensions/_cython_magic_90417133dbca0c2bc9fd1c6311cfcedc.cpp -o /home/asif/.cython/brian_extensions/home/asif/.cython/brian_extensions/_cython_magic_90417133dbca0c2bc9fd1c6311cfcedc.o -w -O3 -ffast-math -fno-finite-math-only -march=native -std=c++11
# INFO:root:x86_64-linux-gnu-g++ -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -g -fwrapv -O2 /home/asif/.cython/brian_extensions/home/asif/.cython/brian_extensions/_cython_magic_90417133dbca0c2bc9fd1c6311cfcedc.o -L/home/asif/lava-dl/.venv/lib -L/usr/lib/x86_64-linux-gnu -Wl,--enable-new-dtags,-R/home/asif/lava-dl/.venv/lib -o /home/asif/.cython/brian_extensions/_cython_magic_90417133dbca0c2bc9fd1c6311cfcedc.cpython-310-x86_64-linux-gnu.so
# INFO:root:building '_cython_magic_420d9aedf5708efbb2fc5d654f67e50d' extension
# INFO:root:x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -I/home/asif/lava-dl/.venv/include -I/home/asif/lava-dl/.venv/lib/python3.10/site-packages/numpy/core/include -I/home/asif/lava-dl/.venv/lib/python3.10/site-packages/brian2/synapses -I/home/asif/lava-dl/.venv/include -I/usr/include/python3.10 -c /home/asif/.cython/brian_extensions/_cython_magic_420d9aedf5708efbb2fc5d654f67e50d.cpp -o /home/asif/.cython/brian_extensions/home/asif/.cython/brian_extensions/_cython_magic_420d9aedf5708efbb2fc5d654f67e50d.o -w -O3 -ffast-math -fno-finite-math-only -march=native -std=c++11
# INFO:root:x86_64-linux-gnu-g++ -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -g -fwrapv -O2 /home/asif/.cython/brian_extensions/home/asif/.cython/brian_extensions/_cython_magic_420d9aedf5708efbb2fc5d654f67e50d.o -L/home/asif/lava-dl/.venv/lib -L/usr/lib/x86_64-linux-gnu -Wl,--enable-new-dtags,-R/home/asif/lava-dl/.venv/lib -o /home/asif/.cython/brian_extensions/_cython_magic_420d9aedf5708efbb2fc5d654f67e50d.cpython-310-x86_64-linux-gnu.so
# INFO:root:building '_cython_magic_66d62b822268f51c91960248fa7106e5' extension
# INFO:root:x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -I/home/asif/lava-dl/.venv/include -I/home/asif/lava-dl/.venv/lib/python3.10/site-packages/numpy/core/include -I/home/asif/lava-dl/.venv/lib/python3.10/site-packages/brian2/synapses -I/home/asif/lava-dl/.venv/include -I/usr/include/python3.10 -c /home/asif/.cython/brian_extensions/_cython_magic_66d62b822268f51c91960248fa7106e5.cpp -o /home/asif/.cython/brian_extensions/home/asif/.cython/brian_extensions/_cython_magic_66d62b822268f51c91960248fa7106e5.o -w -O3 -ffast-math -fno-finite-math-only -march=native -std=c++11
# INFO:root:x86_64-linux-gnu-g++ -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -g -fwrapv -O2 /home/asif/.cython/brian_extensions/home/asif/.cython/brian_extensions/_cython_magic_66d62b822268f51c91960248fa7106e5.o -L/home/asif/lava-dl/.venv/lib -L/usr/lib/x86_64-linux-gnu -Wl,--enable-new-dtags,-R/home/asif/lava-dl/.venv/lib -o /home/asif/.cython/brian_extensions/_cython_magic_66d62b822268f51c91960248fa7106e5.cpython-310-x86_64-linux-gnu.so
# INFO:root:building '_cython_magic_f1bdd33fd54913efc08cee9804ae49f0' extension
# INFO:root:x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -I/home/asif/lava-dl/.venv/include -I/home/asif/lava-dl/.venv/lib/python3.10/site-packages/numpy/core/include -I/home/asif/lava-dl/.venv/lib/python3.10/site-packages/brian2/synapses -I/home/asif/lava-dl/.venv/include -I/usr/include/python3.10 -c /home/asif/.cython/brian_extensions/_cython_magic_f1bdd33fd54913efc08cee9804ae49f0.cpp -o /home/asif/.cython/brian_extensions/home/asif/.cython/brian_extensions/_cython_magic_f1bdd33fd54913efc08cee9804ae49f0.o -w -O3 -ffast-math -fno-finite-math-only -march=native -std=c++11
# INFO:root:x86_64-linux-gnu-g++ -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -g -fwrapv -O2 /home/asif/.cython/brian_extensions/home/asif/.cython/brian_extensions/_cython_magic_f1bdd33fd54913efc08cee9804ae49f0.o -L/home/asif/lava-dl/.venv/lib -L/usr/lib/x86_64-linux-gnu -Wl,--enable-new-dtags,-R/home/asif/lava-dl/.venv/lib -o /home/asif/.cython/brian_extensions/_cython_magic_f1bdd33fd54913efc08cee9804ae49f0.cpython-310-x86_64-linux-gnu.so
# INFO:root:building '_cython_magic_902a15197c72cdd90c8eb034c407aa8e' extension
# INFO:root:x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -I/home/asif/lava-dl/.venv/include -I/home/asif/lava-dl/.venv/lib/python3.10/site-packages/numpy/core/include -I/home/asif/lava-dl/.venv/lib/python3.10/site-packages/brian2/synapses -I/home/asif/lava-dl/.venv/include -I/usr/include/python3.10 -c /home/asif/.cython/brian_extensions/_cython_magic_902a15197c72cdd90c8eb034c407aa8e.cpp -o /home/asif/.cython/brian_extensions/home/asif/.cython/brian_extensions/_cython_magic_902a15197c72cdd90c8eb034c407aa8e.o -w -O3 -ffast-math -fno-finite-math-only -march=native -std=c++11
# INFO:root:x86_64-linux-gnu-g++ -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -g -fwrapv -O2 /home/asif/.cython/brian_extensions/home/asif/.cython/brian_extensions/_cython_magic_902a15197c72cdd90c8eb034c407aa8e.o -L/home/asif/lava-dl/.venv/lib -L/usr/lib/x86_64-linux-gnu -Wl,--enable-new-dtags,-R/home/asif/lava-dl/.venv/lib -o /home/asif/.cython/brian_extensions/_cython_magic_902a15197c72cdd90c8eb034c407aa8e.cpython-310-x86_64-linux-gnu.so
# INFO:root:building '_cython_magic_42fc5bc4c0cb72633cec8e48fe79652d' extension
# INFO:root:x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -I/home/asif/lava-dl/.venv/include -I/home/asif/lava-dl/.venv/lib/python3.10/site-packages/numpy/core/include -I/home/asif/lava-dl/.venv/lib/python3.10/site-packages/brian2/synapses -I/home/asif/lava-dl/.venv/include -I/usr/include/python3.10 -c /home/asif/.cython/brian_extensions/_cython_magic_42fc5bc4c0cb72633cec8e48fe79652d.cpp -o /home/asif/.cython/brian_extensions/home/asif/.cython/brian_extensions/_cython_magic_42fc5bc4c0cb72633cec8e48fe79652d.o -w -O3 -ffast-math -fno-finite-math-only -march=native -std=c++11
# INFO:root:x86_64-linux-gnu-g++ -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -g -fwrapv -O2 /home/asif/.cython/brian_extensions/home/asif/.cython/brian_extensions/_cython_magic_42fc5bc4c0cb72633cec8e48fe79652d.o -L/home/asif/lava-dl/.venv/lib -L/usr/lib/x86_64-linux-gnu -Wl,--enable-new-dtags,-R/home/asif/lava-dl/.venv/lib -o /home/asif/.cython/brian_extensions/_cython_magic_42fc5bc4c0cb72633cec8e48fe79652d.cpython-310-x86_64-linux-gnu.so
# Starting simulation at t=0. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=0.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=1. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=1.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=2. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=2.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=3. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=3.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=4. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=4.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=6. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=6.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=7. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=7.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=8. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=8.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=9. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=9.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=10. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=10.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=11. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=11.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=12. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=12.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=13. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=13.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=14. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=14.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=15. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=15.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=16. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=16.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=17. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=17.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=18. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=18.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=19. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=19.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=20. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=20.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=21. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=21.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=22. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=22.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=23. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=23.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=24. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=24.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=25. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=25.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=26. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=26.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=27. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=27.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=28. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=28.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=29. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=29.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=30. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=30.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=31. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=31.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=32. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=32.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=33. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=33.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=34. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=34.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=35. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=35.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=36. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=36.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=37. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=37.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=38. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=38.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=39. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=39.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=40. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=40.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=41. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=41.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=42. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=42.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=43. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=43.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=44. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=44.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=45. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=45.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=46. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=46.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=47. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=47.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=48. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=48.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=49. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=49.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=50. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=50.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=51. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=51.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=52. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=52.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# runs done: 100 of 10000
# Starting simulation at t=53. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=53.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=54. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=54.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=55. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=55.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=56. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=56.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=57. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=57.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=58. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=58.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=59. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=59.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=60. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=60.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=61. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=61.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=62. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=62.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=63. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=63.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=64. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=64.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=65. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=65.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=66. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=66.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=67. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=67.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=68. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=68.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=69. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=69.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=70. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=70.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=71. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=71.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=72. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=72.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=73. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=73.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=74. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=74.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=75. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=75.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=76. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=76.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=77. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=77.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=78. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=78.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=79. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=79.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=80. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=80.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=81. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=81.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=82. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=82.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=83. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=83.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=84. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=84.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=85. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=85.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=86. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=86.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=87. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=87.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=88. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=88.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=89. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=89.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=90. s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=90.5 s for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# ...
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.0765 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.077 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.0775 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.078 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.0785 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.079 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.0795 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.08 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.0805 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.081 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.0815 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.082 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.0825 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.083 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.0835 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.084 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.0845 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.085 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.0855 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.086 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.0865 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.087 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.0875 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.088 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.0885 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.089 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.0895 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.09 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.0905 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.091 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.0915 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.092 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.0925 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.093 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.0935 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.094 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.0945 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.095 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.0955 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.096 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.0965 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.097 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.0975 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.098 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.0985 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.099 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.0995 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.1 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.1005 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.101 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.1015 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.102 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.1025 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.103 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.1035 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.104 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.1045 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.105 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.1055 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.106 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.1065 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.107 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.1075 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.108 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.1085 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.109 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.1095 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.11 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.1105 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.111 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.1115 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.112 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.1125 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.113 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.1135 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# runs done: 9900 of 10000
# Starting simulation at t=5.114 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.1145 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.115 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.1155 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.116 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.1165 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.117 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.1175 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.118 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.1185 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.119 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.1195 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.12 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.1205 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.121 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.1215 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.122 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.1225 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.123 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.1235 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.124 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.1245 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.125 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.1255 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.126 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.1265 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.127 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.1275 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.128 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.1285 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.129 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.1295 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.13 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.1305 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.131 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.1315 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.132 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.1325 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.133 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.1335 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.134 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.1345 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.135 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.1355 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.136 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.1365 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.137 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.1375 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.138 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.1385 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.139 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.1395 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.14 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.1405 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.141 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.1415 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.142 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.1425 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.143 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.1435 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.144 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.1445 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.145 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.1455 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.146 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.1465 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.147 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.1475 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.148 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.1485 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.149 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.1495 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.15 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.1505 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.151 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.1515 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.152 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.1525 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.153 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.1535 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.154 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.1545 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.155 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.1555 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.156 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.1565 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.157 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.1575 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.158 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.1585 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.159 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.1595 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.16 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.1605 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.161 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.1615 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.162 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.1625 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s
# Starting simulation at t=5.163 ks for a duration of 0.35 s
# 0.35 s (100%) simulated in < 1s

# %%
#------------------------------------------------------------------------------
# save results
#------------------------------------------------------------------------------
print( 'save results')
if not test_mode:
    save_theta()
if not test_mode:
    save_connections()
else:
    np.save('/home/asif/lava-dl/Tasks/Task_8/Brian2STDPMNIST/activity/resultPopVecs' + str(num_examples), result_monitor)
    np.save('/home/asif/lava-dl/Tasks/Task_8/Brian2STDPMNIST/activity/inputNumbers' + str(num_examples), input_numbers)
# Out:
# save results

# %%
#------------------------------------------------------------------------------
# plot results
#------------------------------------------------------------------------------
if rate_monitors:
    b2.figure(fig_num)
    fig_num += 1
    for i, name in enumerate(rate_monitors):
        b2.subplot(len(rate_monitors), 1, 1+i)
        b2.plot(rate_monitors[name].t/b2.second, rate_monitors[name].rate, '.')
        b2.title('Rates of population ' + name)

if spike_monitors:
    b2.figure(fig_num)
    fig_num += 1
    for i, name in enumerate(spike_monitors):
        b2.subplot(len(spike_monitors), 1, 1+i)
        b2.plot(spike_monitors[name].t/b2.ms, spike_monitors[name].i, '.')
        b2.title('Spikes of population ' + name)

if spike_counters:
    b2.figure(fig_num)
    fig_num += 1
    b2.plot(spike_monitors['Ae'].count[:])
    b2.title('Spike count of population Ae')
